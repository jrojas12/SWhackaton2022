# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfRaw = pd.read_csv('owid-co2-data.csv')

dfRaw['year'] = pd.to_datetime(dfRaw['year'], format='%Y')

df = dfRaw.set_index('year')

# %%
# Calculate total production per year
dfSum = pd.DataFrame()

dfSum['co2'] = df.groupby(['year'])['co2'].sum()
dfSum['year'] = dfSum.index
dfSum['year'] = dfSum.year.dt.year

plt.plot(dfSum['year'], dfSum['co2'])

plt.title("Total CO2 emission per year");

# %%
# ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

y = train

ARMAmodel = SARIMAX(y, order = (1,2,2))
ARMAmodel_fit = ARMAmodel.fit()
num_years = 30
forecast = ARMAmodel2_fit.forecast(num_years)

year_start = y.index[-1].year+1
years = [*range(year_start, year_start + num_years)]

forecastDf = pd.DataFrame(index = years)
forecastDf['co2'] = forecast.values
forecastDf['co2']
forecastDf.year = forecastDf.index

forecastDf['co2NEW'] = forecastDf['co2'] + np.median(y)
# Out:
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# D:\Programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
dfSum = dfSum[dfSum.year > 1700]
train =dfSum[dfSum.year <= 2020]['co2']
test = dfSum[dfSum.year > 2020]['co2']

trainData = dfSum[dfSum.year <= 2020]
testData = dfSum[dfSum.year > 2020]
plt.plot(trainData.year,trainData.co2)
plt.plot(testData.year,testData.co2)
plt.plot(forecastDf.year,forecastDf.co2NEW)

# %%
### Predictions per country
feature = 'co2'
githcountries = df.country.unique()
co2PredDf = pd.DataFrame()
for country in countries:
    countryDf = df[df['country'] == country]
    countryDf['year'] = countryDf.index

    year_start = 2022
    countryDf['year'] = countryDf.year.dt.year
    train =countryDf[countryDf.year <= 2022][feature]

    y = train

    ARMAmodel = SARIMAX(y, order = (5,2,2))
    ARMAmodel_fit = ARMAmodel.fit()
    num_years = 10
    forecast = ARMAmodel_fit.forecast(num_years)
    forecast_norm = forecast + np.median(y)


    
    years = [*range(year_start, year_start + num_years)]
    
    forecastDf = pd.DataFrame({'year':years, feature:forecast_norm})
    forecastDf['country'] = country
    co2PredDf = co2PredDf.append(forecastDf)

co2PredDf.to_csv('co2_predictions_norm.csv')
# Out:
# D:\Programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# D:\Programs\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# ...

# %%
co2PredDf[co2PredDf.country == 'Canada']
# Out:
#             year         co2 country
# 2021-01-01  2022  561.861780  Canada
# 2022-01-01  2023  571.453414  Canada
# 2023-01-01  2024  569.221102  Canada
# 2024-01-01  2025  561.340470  Canada
# 2025-01-01  2026  557.864056  Canada
# 2026-01-01  2027  562.635403  Canada
# 2027-01-01  2028  563.382328  Canada
# 2028-01-01  2029  561.791905  Canada
# 2029-01-01  2030  561.745102  Canada
# 2030-01-01  2031  563.591491  Canada

# %%
dfCanada = dfRaw[dfRaw.country == 'Canada']
dfCanada['year'] = dfCanada['year'].dt.year
plt.plot(dfCanada['year'],dfCanada['co2'])co2PredDf[co2PredDf.country == 'Canada']

# co2PredDf[co2PredDf.country == 'Canada']
# Out:
# D:\Programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
